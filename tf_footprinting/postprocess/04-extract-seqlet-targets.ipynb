# %%
import gzip
import h5py
import numpy as np

SAMPLE="HSC"

BED_PKS= f"/work/aaa/projects/chrombpnet-devmult/pipeline/resources/peaks/{SAMPLE}/{SAMPLE}.no_blacklist.bed"
H5_SCORES= f"/work/aaa/projects/chrombpnet-devmult/pipeline/results/chrombpnet_nobias/pretrained_bias/{SAMPLE}/mean/modisco/{SAMPLE}_mean.counts_scores.modisco.h5"
BEDPE_OUT=f"/work/aaa/projects/chrombpnet-devmult/scratch/bed/HSC_mean.seqlet_peak_pairs.bedpe.gz"

WINDOW_SIZE=500

# %%
# Open the HDF5 file in read mode
with h5py.File(H5_SCORES, "r") as f:
    # Function to recursively print groups, datasets, and attributes
    def explore_h5(name, obj):
        if isinstance(obj, h5py.Group):
            print(f"Group: {name}")
        elif isinstance(obj, h5py.Dataset):
            print(f"Dataset: {name} | Shape: {obj.shape} | Type: {obj.dtype}")
            if obj.attrs:  # Check for attributes
                print(f"  Attributes: {dict(obj.attrs)}")

    f.visititems(explore_h5)
# Out:
# Group: pos_patterns
# Group: pos_patterns/pattern_0
# Dataset: pos_patterns/pattern_0/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/seqlets
# Dataset: pos_patterns/pattern_0/seqlets/contrib_scores | Shape: (45009, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/seqlets/end | Shape: (45009,) | Type: int64
# Dataset: pos_patterns/pattern_0/seqlets/example_idx | Shape: (45009,) | Type: int64
# Dataset: pos_patterns/pattern_0/seqlets/hypothetical_contribs | Shape: (45009, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/seqlets/is_revcomp | Shape: (45009,) | Type: bool
# Dataset: pos_patterns/pattern_0/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/seqlets/sequence | Shape: (45009, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/seqlets/start | Shape: (45009,) | Type: int64
# Dataset: pos_patterns/pattern_0/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_0
# Dataset: pos_patterns/pattern_0/subpattern_0/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_0/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_0/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_0/seqlets/contrib_scores | Shape: (4884, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_0/seqlets/end | Shape: (4884,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_0/seqlets/example_idx | Shape: (4884,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_0/seqlets/hypothetical_contribs | Shape: (4884, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_0/seqlets/is_revcomp | Shape: (4884,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_0/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_0/seqlets/sequence | Shape: (4884, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_0/seqlets/start | Shape: (4884,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_0/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_1
# Dataset: pos_patterns/pattern_0/subpattern_1/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_1/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_1/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_1/seqlets/contrib_scores | Shape: (4751, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_1/seqlets/end | Shape: (4751,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_1/seqlets/example_idx | Shape: (4751,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_1/seqlets/hypothetical_contribs | Shape: (4751, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_1/seqlets/is_revcomp | Shape: (4751,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_1/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_1/seqlets/sequence | Shape: (4751, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_1/seqlets/start | Shape: (4751,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_1/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_10
# Dataset: pos_patterns/pattern_0/subpattern_10/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_10/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_10/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_10/seqlets/contrib_scores | Shape: (1300, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_10/seqlets/end | Shape: (1300,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_10/seqlets/example_idx | Shape: (1300,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_10/seqlets/hypothetical_contribs | Shape: (1300, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_10/seqlets/is_revcomp | Shape: (1300,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_10/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_10/seqlets/sequence | Shape: (1300, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_10/seqlets/start | Shape: (1300,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_10/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_11
# Dataset: pos_patterns/pattern_0/subpattern_11/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_11/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_11/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_11/seqlets/contrib_scores | Shape: (868, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_11/seqlets/end | Shape: (868,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_11/seqlets/example_idx | Shape: (868,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_11/seqlets/hypothetical_contribs | Shape: (868, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_11/seqlets/is_revcomp | Shape: (868,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_11/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_11/seqlets/sequence | Shape: (868, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_11/seqlets/start | Shape: (868,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_11/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_12
# Dataset: pos_patterns/pattern_0/subpattern_12/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_12/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_12/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_12/seqlets/contrib_scores | Shape: (851, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_12/seqlets/end | Shape: (851,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_12/seqlets/example_idx | Shape: (851,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_12/seqlets/hypothetical_contribs | Shape: (851, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_12/seqlets/is_revcomp | Shape: (851,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_12/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_12/seqlets/sequence | Shape: (851, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_12/seqlets/start | Shape: (851,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_12/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_13
# Dataset: pos_patterns/pattern_0/subpattern_13/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_13/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_13/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_13/seqlets/contrib_scores | Shape: (749, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_13/seqlets/end | Shape: (749,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_13/seqlets/example_idx | Shape: (749,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_13/seqlets/hypothetical_contribs | Shape: (749, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_13/seqlets/is_revcomp | Shape: (749,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_13/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_13/seqlets/sequence | Shape: (749, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_13/seqlets/start | Shape: (749,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_13/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_14
# Dataset: pos_patterns/pattern_0/subpattern_14/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_14/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_14/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_14/seqlets/contrib_scores | Shape: (694, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_14/seqlets/end | Shape: (694,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_14/seqlets/example_idx | Shape: (694,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_14/seqlets/hypothetical_contribs | Shape: (694, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_14/seqlets/is_revcomp | Shape: (694,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_14/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_14/seqlets/sequence | Shape: (694, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_14/seqlets/start | Shape: (694,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_14/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_15
# Dataset: pos_patterns/pattern_0/subpattern_15/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_15/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_15/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_15/seqlets/contrib_scores | Shape: (680, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_15/seqlets/end | Shape: (680,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_15/seqlets/example_idx | Shape: (680,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_15/seqlets/hypothetical_contribs | Shape: (680, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_15/seqlets/is_revcomp | Shape: (680,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_15/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_15/seqlets/sequence | Shape: (680, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_15/seqlets/start | Shape: (680,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_15/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_16
# Dataset: pos_patterns/pattern_0/subpattern_16/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_16/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_16/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_16/seqlets/contrib_scores | Shape: (655, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_16/seqlets/end | Shape: (655,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_16/seqlets/example_idx | Shape: (655,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_16/seqlets/hypothetical_contribs | Shape: (655, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_16/seqlets/is_revcomp | Shape: (655,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_16/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_16/seqlets/sequence | Shape: (655, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_16/seqlets/start | Shape: (655,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_16/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_17
# Dataset: pos_patterns/pattern_0/subpattern_17/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_17/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_17/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_17/seqlets/contrib_scores | Shape: (520, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_17/seqlets/end | Shape: (520,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_17/seqlets/example_idx | Shape: (520,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_17/seqlets/hypothetical_contribs | Shape: (520, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_17/seqlets/is_revcomp | Shape: (520,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_17/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_17/seqlets/sequence | Shape: (520, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_17/seqlets/start | Shape: (520,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_17/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_18
# Dataset: pos_patterns/pattern_0/subpattern_18/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_18/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_18/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_18/seqlets/contrib_scores | Shape: (518, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_18/seqlets/end | Shape: (518,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_18/seqlets/example_idx | Shape: (518,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_18/seqlets/hypothetical_contribs | Shape: (518, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_18/seqlets/is_revcomp | Shape: (518,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_18/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_18/seqlets/sequence | Shape: (518, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_18/seqlets/start | Shape: (518,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_18/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_19
# Dataset: pos_patterns/pattern_0/subpattern_19/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_19/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_19/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_19/seqlets/contrib_scores | Shape: (424, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_19/seqlets/end | Shape: (424,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_19/seqlets/example_idx | Shape: (424,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_19/seqlets/hypothetical_contribs | Shape: (424, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_19/seqlets/is_revcomp | Shape: (424,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_19/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_19/seqlets/sequence | Shape: (424, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_19/seqlets/start | Shape: (424,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_19/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_2
# Dataset: pos_patterns/pattern_0/subpattern_2/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_2/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_2/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_2/seqlets/contrib_scores | Shape: (4639, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_2/seqlets/end | Shape: (4639,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_2/seqlets/example_idx | Shape: (4639,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_2/seqlets/hypothetical_contribs | Shape: (4639, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_2/seqlets/is_revcomp | Shape: (4639,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_2/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_2/seqlets/sequence | Shape: (4639, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_2/seqlets/start | Shape: (4639,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_2/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_20
# Dataset: pos_patterns/pattern_0/subpattern_20/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_20/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_20/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_20/seqlets/contrib_scores | Shape: (210, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_20/seqlets/end | Shape: (210,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_20/seqlets/example_idx | Shape: (210,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_20/seqlets/hypothetical_contribs | Shape: (210, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_20/seqlets/is_revcomp | Shape: (210,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_20/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_20/seqlets/sequence | Shape: (210, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_20/seqlets/start | Shape: (210,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_20/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_21
# Dataset: pos_patterns/pattern_0/subpattern_21/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_21/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_21/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_21/seqlets/contrib_scores | Shape: (195, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_21/seqlets/end | Shape: (195,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_21/seqlets/example_idx | Shape: (195,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_21/seqlets/hypothetical_contribs | Shape: (195, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_21/seqlets/is_revcomp | Shape: (195,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_21/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_21/seqlets/sequence | Shape: (195, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_21/seqlets/start | Shape: (195,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_21/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_22
# Dataset: pos_patterns/pattern_0/subpattern_22/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_22/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_22/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_22/seqlets/contrib_scores | Shape: (159, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_22/seqlets/end | Shape: (159,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_22/seqlets/example_idx | Shape: (159,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_22/seqlets/hypothetical_contribs | Shape: (159, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_22/seqlets/is_revcomp | Shape: (159,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_22/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_22/seqlets/sequence | Shape: (159, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_22/seqlets/start | Shape: (159,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_22/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_23
# Dataset: pos_patterns/pattern_0/subpattern_23/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_23/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_23/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_23/seqlets/contrib_scores | Shape: (141, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_23/seqlets/end | Shape: (141,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_23/seqlets/example_idx | Shape: (141,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_23/seqlets/hypothetical_contribs | Shape: (141, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_23/seqlets/is_revcomp | Shape: (141,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_23/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_23/seqlets/sequence | Shape: (141, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_23/seqlets/start | Shape: (141,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_23/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_24
# Dataset: pos_patterns/pattern_0/subpattern_24/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_24/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_24/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_24/seqlets/contrib_scores | Shape: (127, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_24/seqlets/end | Shape: (127,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_24/seqlets/example_idx | Shape: (127,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_24/seqlets/hypothetical_contribs | Shape: (127, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_24/seqlets/is_revcomp | Shape: (127,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_24/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_24/seqlets/sequence | Shape: (127, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_24/seqlets/start | Shape: (127,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_24/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_25
# Dataset: pos_patterns/pattern_0/subpattern_25/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_25/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_25/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_25/seqlets/contrib_scores | Shape: (86, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_25/seqlets/end | Shape: (86,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_25/seqlets/example_idx | Shape: (86,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_25/seqlets/hypothetical_contribs | Shape: (86, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_25/seqlets/is_revcomp | Shape: (86,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_25/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_25/seqlets/sequence | Shape: (86, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_25/seqlets/start | Shape: (86,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_25/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_3
# Dataset: pos_patterns/pattern_0/subpattern_3/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_3/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_3/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_3/seqlets/contrib_scores | Shape: (4074, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_3/seqlets/end | Shape: (4074,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_3/seqlets/example_idx | Shape: (4074,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_3/seqlets/hypothetical_contribs | Shape: (4074, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_3/seqlets/is_revcomp | Shape: (4074,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_3/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_3/seqlets/sequence | Shape: (4074, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_3/seqlets/start | Shape: (4074,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_3/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_4
# Dataset: pos_patterns/pattern_0/subpattern_4/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_4/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_4/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_4/seqlets/contrib_scores | Shape: (3920, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_4/seqlets/end | Shape: (3920,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_4/seqlets/example_idx | Shape: (3920,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_4/seqlets/hypothetical_contribs | Shape: (3920, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_4/seqlets/is_revcomp | Shape: (3920,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_4/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_4/seqlets/sequence | Shape: (3920, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_4/seqlets/start | Shape: (3920,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_4/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_5
# Dataset: pos_patterns/pattern_0/subpattern_5/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_5/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_5/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_5/seqlets/contrib_scores | Shape: (3882, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_5/seqlets/end | Shape: (3882,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_5/seqlets/example_idx | Shape: (3882,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_5/seqlets/hypothetical_contribs | Shape: (3882, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_5/seqlets/is_revcomp | Shape: (3882,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_5/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_5/seqlets/sequence | Shape: (3882, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_5/seqlets/start | Shape: (3882,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_5/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_6
# Dataset: pos_patterns/pattern_0/subpattern_6/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_6/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_6/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_6/seqlets/contrib_scores | Shape: (3279, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_6/seqlets/end | Shape: (3279,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_6/seqlets/example_idx | Shape: (3279,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_6/seqlets/hypothetical_contribs | Shape: (3279, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_6/seqlets/is_revcomp | Shape: (3279,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_6/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_6/seqlets/sequence | Shape: (3279, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_6/seqlets/start | Shape: (3279,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_6/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_7
# Dataset: pos_patterns/pattern_0/subpattern_7/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_7/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_7/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_7/seqlets/contrib_scores | Shape: (3037, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_7/seqlets/end | Shape: (3037,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_7/seqlets/example_idx | Shape: (3037,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_7/seqlets/hypothetical_contribs | Shape: (3037, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_7/seqlets/is_revcomp | Shape: (3037,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_7/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_7/seqlets/sequence | Shape: (3037, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_7/seqlets/start | Shape: (3037,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_7/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_8
# Dataset: pos_patterns/pattern_0/subpattern_8/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_8/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_8/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_8/seqlets/contrib_scores | Shape: (2463, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_8/seqlets/end | Shape: (2463,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_8/seqlets/example_idx | Shape: (2463,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_8/seqlets/hypothetical_contribs | Shape: (2463, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_8/seqlets/is_revcomp | Shape: (2463,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_8/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_8/seqlets/sequence | Shape: (2463, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_8/seqlets/start | Shape: (2463,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_8/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_9
# Dataset: pos_patterns/pattern_0/subpattern_9/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_0/subpattern_9/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_0/subpattern_9/seqlets
# Dataset: pos_patterns/pattern_0/subpattern_9/seqlets/contrib_scores | Shape: (1903, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_9/seqlets/end | Shape: (1903,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_9/seqlets/example_idx | Shape: (1903,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_9/seqlets/hypothetical_contribs | Shape: (1903, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_9/seqlets/is_revcomp | Shape: (1903,) | Type: bool
# Dataset: pos_patterns/pattern_0/subpattern_9/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_9/seqlets/sequence | Shape: (1903, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_0/subpattern_9/seqlets/start | Shape: (1903,) | Type: int64
# Dataset: pos_patterns/pattern_0/subpattern_9/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1
# Dataset: pos_patterns/pattern_1/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_1/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/seqlets
# Dataset: pos_patterns/pattern_1/seqlets/contrib_scores | Shape: (30832, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/seqlets/end | Shape: (30832,) | Type: int64
# Dataset: pos_patterns/pattern_1/seqlets/example_idx | Shape: (30832,) | Type: int64
# Dataset: pos_patterns/pattern_1/seqlets/hypothetical_contribs | Shape: (30832, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/seqlets/is_revcomp | Shape: (30832,) | Type: bool
# Dataset: pos_patterns/pattern_1/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_1/seqlets/sequence | Shape: (30832, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/seqlets/start | Shape: (30832,) | Type: int64
# Dataset: pos_patterns/pattern_1/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_0
# Dataset: pos_patterns/pattern_1/subpattern_0/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_1/subpattern_0/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_0/seqlets
# Dataset: pos_patterns/pattern_1/subpattern_0/seqlets/contrib_scores | Shape: (5432, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_0/seqlets/end | Shape: (5432,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_0/seqlets/example_idx | Shape: (5432,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_0/seqlets/hypothetical_contribs | Shape: (5432, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_0/seqlets/is_revcomp | Shape: (5432,) | Type: bool
# Dataset: pos_patterns/pattern_1/subpattern_0/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_0/seqlets/sequence | Shape: (5432, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_0/seqlets/start | Shape: (5432,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_0/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_1
# Dataset: pos_patterns/pattern_1/subpattern_1/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_1/subpattern_1/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_1/seqlets
# Dataset: pos_patterns/pattern_1/subpattern_1/seqlets/contrib_scores | Shape: (4156, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_1/seqlets/end | Shape: (4156,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_1/seqlets/example_idx | Shape: (4156,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_1/seqlets/hypothetical_contribs | Shape: (4156, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_1/seqlets/is_revcomp | Shape: (4156,) | Type: bool
# Dataset: pos_patterns/pattern_1/subpattern_1/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_1/seqlets/sequence | Shape: (4156, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_1/seqlets/start | Shape: (4156,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_1/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_2
# Dataset: pos_patterns/pattern_1/subpattern_2/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_1/subpattern_2/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_2/seqlets
# Dataset: pos_patterns/pattern_1/subpattern_2/seqlets/contrib_scores | Shape: (3727, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_2/seqlets/end | Shape: (3727,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_2/seqlets/example_idx | Shape: (3727,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_2/seqlets/hypothetical_contribs | Shape: (3727, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_2/seqlets/is_revcomp | Shape: (3727,) | Type: bool
# Dataset: pos_patterns/pattern_1/subpattern_2/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_2/seqlets/sequence | Shape: (3727, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_2/seqlets/start | Shape: (3727,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_2/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_3
# Dataset: pos_patterns/pattern_1/subpattern_3/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_1/subpattern_3/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_3/seqlets
# Dataset: pos_patterns/pattern_1/subpattern_3/seqlets/contrib_scores | Shape: (3718, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_3/seqlets/end | Shape: (3718,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_3/seqlets/example_idx | Shape: (3718,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_3/seqlets/hypothetical_contribs | Shape: (3718, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_3/seqlets/is_revcomp | Shape: (3718,) | Type: bool
# Dataset: pos_patterns/pattern_1/subpattern_3/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_3/seqlets/sequence | Shape: (3718, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_3/seqlets/start | Shape: (3718,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_3/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_4
# Dataset: pos_patterns/pattern_1/subpattern_4/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_1/subpattern_4/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_4/seqlets
# Dataset: pos_patterns/pattern_1/subpattern_4/seqlets/contrib_scores | Shape: (3290, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_4/seqlets/end | Shape: (3290,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_4/seqlets/example_idx | Shape: (3290,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_4/seqlets/hypothetical_contribs | Shape: (3290, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_4/seqlets/is_revcomp | Shape: (3290,) | Type: bool
# Dataset: pos_patterns/pattern_1/subpattern_4/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_4/seqlets/sequence | Shape: (3290, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_4/seqlets/start | Shape: (3290,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_4/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_5
# Dataset: pos_patterns/pattern_1/subpattern_5/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_1/subpattern_5/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_5/seqlets
# Dataset: pos_patterns/pattern_1/subpattern_5/seqlets/contrib_scores | Shape: (3028, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_5/seqlets/end | Shape: (3028,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_5/seqlets/example_idx | Shape: (3028,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_5/seqlets/hypothetical_contribs | Shape: (3028, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_5/seqlets/is_revcomp | Shape: (3028,) | Type: bool
# Dataset: pos_patterns/pattern_1/subpattern_5/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_5/seqlets/sequence | Shape: (3028, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_5/seqlets/start | Shape: (3028,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_5/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_6
# Dataset: pos_patterns/pattern_1/subpattern_6/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_1/subpattern_6/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_6/seqlets
# Dataset: pos_patterns/pattern_1/subpattern_6/seqlets/contrib_scores | Shape: (2858, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_6/seqlets/end | Shape: (2858,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_6/seqlets/example_idx | Shape: (2858,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_6/seqlets/hypothetical_contribs | Shape: (2858, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_6/seqlets/is_revcomp | Shape: (2858,) | Type: bool
# Dataset: pos_patterns/pattern_1/subpattern_6/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_6/seqlets/sequence | Shape: (2858, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_6/seqlets/start | Shape: (2858,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_6/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_7
# Dataset: pos_patterns/pattern_1/subpattern_7/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_1/subpattern_7/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_7/seqlets
# Dataset: pos_patterns/pattern_1/subpattern_7/seqlets/contrib_scores | Shape: (2494, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_7/seqlets/end | Shape: (2494,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_7/seqlets/example_idx | Shape: (2494,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_7/seqlets/hypothetical_contribs | Shape: (2494, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_7/seqlets/is_revcomp | Shape: (2494,) | Type: bool
# Dataset: pos_patterns/pattern_1/subpattern_7/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_7/seqlets/sequence | Shape: (2494, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_7/seqlets/start | Shape: (2494,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_7/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_8
# Dataset: pos_patterns/pattern_1/subpattern_8/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_1/subpattern_8/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_8/seqlets
# Dataset: pos_patterns/pattern_1/subpattern_8/seqlets/contrib_scores | Shape: (1981, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_8/seqlets/end | Shape: (1981,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_8/seqlets/example_idx | Shape: (1981,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_8/seqlets/hypothetical_contribs | Shape: (1981, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_8/seqlets/is_revcomp | Shape: (1981,) | Type: bool
# Dataset: pos_patterns/pattern_1/subpattern_8/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_8/seqlets/sequence | Shape: (1981, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_8/seqlets/start | Shape: (1981,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_8/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_9
# Dataset: pos_patterns/pattern_1/subpattern_9/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_1/subpattern_9/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_1/subpattern_9/seqlets
# Dataset: pos_patterns/pattern_1/subpattern_9/seqlets/contrib_scores | Shape: (148, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_9/seqlets/end | Shape: (148,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_9/seqlets/example_idx | Shape: (148,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_9/seqlets/hypothetical_contribs | Shape: (148, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_9/seqlets/is_revcomp | Shape: (148,) | Type: bool
# Dataset: pos_patterns/pattern_1/subpattern_9/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_9/seqlets/sequence | Shape: (148, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_1/subpattern_9/seqlets/start | Shape: (148,) | Type: int64
# Dataset: pos_patterns/pattern_1/subpattern_9/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_10
# Dataset: pos_patterns/pattern_10/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_10/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_10/seqlets
# Dataset: pos_patterns/pattern_10/seqlets/contrib_scores | Shape: (1898, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_10/seqlets/end | Shape: (1898,) | Type: int64
# Dataset: pos_patterns/pattern_10/seqlets/example_idx | Shape: (1898,) | Type: int64
# Dataset: pos_patterns/pattern_10/seqlets/hypothetical_contribs | Shape: (1898, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_10/seqlets/is_revcomp | Shape: (1898,) | Type: bool
# Dataset: pos_patterns/pattern_10/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_10/seqlets/sequence | Shape: (1898, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_10/seqlets/start | Shape: (1898,) | Type: int64
# Dataset: pos_patterns/pattern_10/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_10/subpattern_0
# Dataset: pos_patterns/pattern_10/subpattern_0/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_10/subpattern_0/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_10/subpattern_0/seqlets
# Dataset: pos_patterns/pattern_10/subpattern_0/seqlets/contrib_scores | Shape: (317, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_10/subpattern_0/seqlets/end | Shape: (317,) | Type: int64
# Dataset: pos_patterns/pattern_10/subpattern_0/seqlets/example_idx | Shape: (317,) | Type: int64
# Dataset: pos_patterns/pattern_10/subpattern_0/seqlets/hypothetical_contribs | Shape: (317, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_10/subpattern_0/seqlets/is_revcomp | Shape: (317,) | Type: bool
# Dataset: pos_patterns/pattern_10/subpattern_0/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_10/subpattern_0/seqlets/sequence | Shape: (317, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_10/subpattern_0/seqlets/start | Shape: (317,) | Type: int64
# Dataset: pos_patterns/pattern_10/subpattern_0/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_10/subpattern_1
# Dataset: pos_patterns/pattern_10/subpattern_1/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_10/subpattern_1/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_10/subpattern_1/seqlets
# Dataset: pos_patterns/pattern_10/subpattern_1/seqlets/contrib_scores | Shape: (307, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_10/subpattern_1/seqlets/end | Shape: (307,) | Type: int64
# Dataset: pos_patterns/pattern_10/subpattern_1/seqlets/example_idx | Shape: (307,) | Type: int64
# Dataset: pos_patterns/pattern_10/subpattern_1/seqlets/hypothetical_contribs | Shape: (307, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_10/subpattern_1/seqlets/is_revcomp | Shape: (307,) | Type: bool
# Dataset: pos_patterns/pattern_10/subpattern_1/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_10/subpattern_1/seqlets/sequence | Shape: (307, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_10/subpattern_1/seqlets/start | Shape: (307,) | Type: int64
# Dataset: pos_patterns/pattern_10/subpattern_1/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_10/subpattern_2
# Dataset: pos_patterns/pattern_10/subpattern_2/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_10/subpattern_2/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_10/subpattern_2/seqlets
# Dataset: pos_patterns/pattern_10/subpattern_2/seqlets/contrib_scores | Shape: (295, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_10/subpattern_2/seqlets/end | Shape: (295,) | Type: int64
# Dataset: pos_patterns/pattern_10/subpattern_2/seqlets/example_idx | Shape: (295,) | Type: int64
# Dataset: pos_patterns/pattern_10/subpattern_2/seqlets/hypothetical_contribs | Shape: (295, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_10/subpattern_2/seqlets/is_revcomp | Shape: (295,) | Type: bool
# Dataset: pos_patterns/pattern_10/subpattern_2/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_10/subpattern_2/seqlets/sequence | Shape: (295, 30, 4) | Type: float32
# ...
# Dataset: pos_patterns/pattern_8/subpattern_4/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_8/subpattern_5
# Dataset: pos_patterns/pattern_8/subpattern_5/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_8/subpattern_5/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_8/subpattern_5/seqlets
# Dataset: pos_patterns/pattern_8/subpattern_5/seqlets/contrib_scores | Shape: (284, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_5/seqlets/end | Shape: (284,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_5/seqlets/example_idx | Shape: (284,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_5/seqlets/hypothetical_contribs | Shape: (284, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_5/seqlets/is_revcomp | Shape: (284,) | Type: bool
# Dataset: pos_patterns/pattern_8/subpattern_5/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_5/seqlets/sequence | Shape: (284, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_5/seqlets/start | Shape: (284,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_5/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_8/subpattern_6
# Dataset: pos_patterns/pattern_8/subpattern_6/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_8/subpattern_6/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_8/subpattern_6/seqlets
# Dataset: pos_patterns/pattern_8/subpattern_6/seqlets/contrib_scores | Shape: (52, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_6/seqlets/end | Shape: (52,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_6/seqlets/example_idx | Shape: (52,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_6/seqlets/hypothetical_contribs | Shape: (52, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_6/seqlets/is_revcomp | Shape: (52,) | Type: bool
# Dataset: pos_patterns/pattern_8/subpattern_6/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_6/seqlets/sequence | Shape: (52, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_6/seqlets/start | Shape: (52,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_6/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_8/subpattern_7
# Dataset: pos_patterns/pattern_8/subpattern_7/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_8/subpattern_7/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_8/subpattern_7/seqlets
# Dataset: pos_patterns/pattern_8/subpattern_7/seqlets/contrib_scores | Shape: (9, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_7/seqlets/end | Shape: (9,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_7/seqlets/example_idx | Shape: (9,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_7/seqlets/hypothetical_contribs | Shape: (9, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_7/seqlets/is_revcomp | Shape: (9,) | Type: bool
# Dataset: pos_patterns/pattern_8/subpattern_7/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_7/seqlets/sequence | Shape: (9, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_7/seqlets/start | Shape: (9,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_7/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_8/subpattern_8
# Dataset: pos_patterns/pattern_8/subpattern_8/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_8/subpattern_8/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_8/subpattern_8/seqlets
# Dataset: pos_patterns/pattern_8/subpattern_8/seqlets/contrib_scores | Shape: (5, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_8/seqlets/end | Shape: (5,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_8/seqlets/example_idx | Shape: (5,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_8/seqlets/hypothetical_contribs | Shape: (5, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_8/seqlets/is_revcomp | Shape: (5,) | Type: bool
# Dataset: pos_patterns/pattern_8/subpattern_8/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_8/seqlets/sequence | Shape: (5, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_8/subpattern_8/seqlets/start | Shape: (5,) | Type: int64
# Dataset: pos_patterns/pattern_8/subpattern_8/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9
# Dataset: pos_patterns/pattern_9/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_9/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/seqlets
# Dataset: pos_patterns/pattern_9/seqlets/contrib_scores | Shape: (2072, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/seqlets/end | Shape: (2072,) | Type: int64
# Dataset: pos_patterns/pattern_9/seqlets/example_idx | Shape: (2072,) | Type: int64
# Dataset: pos_patterns/pattern_9/seqlets/hypothetical_contribs | Shape: (2072, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/seqlets/is_revcomp | Shape: (2072,) | Type: bool
# Dataset: pos_patterns/pattern_9/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_9/seqlets/sequence | Shape: (2072, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/seqlets/start | Shape: (2072,) | Type: int64
# Dataset: pos_patterns/pattern_9/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_0
# Dataset: pos_patterns/pattern_9/subpattern_0/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_9/subpattern_0/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_0/seqlets
# Dataset: pos_patterns/pattern_9/subpattern_0/seqlets/contrib_scores | Shape: (498, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_0/seqlets/end | Shape: (498,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_0/seqlets/example_idx | Shape: (498,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_0/seqlets/hypothetical_contribs | Shape: (498, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_0/seqlets/is_revcomp | Shape: (498,) | Type: bool
# Dataset: pos_patterns/pattern_9/subpattern_0/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_0/seqlets/sequence | Shape: (498, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_0/seqlets/start | Shape: (498,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_0/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_1
# Dataset: pos_patterns/pattern_9/subpattern_1/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_9/subpattern_1/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_1/seqlets
# Dataset: pos_patterns/pattern_9/subpattern_1/seqlets/contrib_scores | Shape: (345, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_1/seqlets/end | Shape: (345,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_1/seqlets/example_idx | Shape: (345,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_1/seqlets/hypothetical_contribs | Shape: (345, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_1/seqlets/is_revcomp | Shape: (345,) | Type: bool
# Dataset: pos_patterns/pattern_9/subpattern_1/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_1/seqlets/sequence | Shape: (345, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_1/seqlets/start | Shape: (345,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_1/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_2
# Dataset: pos_patterns/pattern_9/subpattern_2/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_9/subpattern_2/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_2/seqlets
# Dataset: pos_patterns/pattern_9/subpattern_2/seqlets/contrib_scores | Shape: (340, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_2/seqlets/end | Shape: (340,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_2/seqlets/example_idx | Shape: (340,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_2/seqlets/hypothetical_contribs | Shape: (340, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_2/seqlets/is_revcomp | Shape: (340,) | Type: bool
# Dataset: pos_patterns/pattern_9/subpattern_2/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_2/seqlets/sequence | Shape: (340, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_2/seqlets/start | Shape: (340,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_2/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_3
# Dataset: pos_patterns/pattern_9/subpattern_3/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_9/subpattern_3/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_3/seqlets
# Dataset: pos_patterns/pattern_9/subpattern_3/seqlets/contrib_scores | Shape: (273, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_3/seqlets/end | Shape: (273,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_3/seqlets/example_idx | Shape: (273,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_3/seqlets/hypothetical_contribs | Shape: (273, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_3/seqlets/is_revcomp | Shape: (273,) | Type: bool
# Dataset: pos_patterns/pattern_9/subpattern_3/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_3/seqlets/sequence | Shape: (273, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_3/seqlets/start | Shape: (273,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_3/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_4
# Dataset: pos_patterns/pattern_9/subpattern_4/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_9/subpattern_4/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_4/seqlets
# Dataset: pos_patterns/pattern_9/subpattern_4/seqlets/contrib_scores | Shape: (216, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_4/seqlets/end | Shape: (216,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_4/seqlets/example_idx | Shape: (216,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_4/seqlets/hypothetical_contribs | Shape: (216, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_4/seqlets/is_revcomp | Shape: (216,) | Type: bool
# Dataset: pos_patterns/pattern_9/subpattern_4/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_4/seqlets/sequence | Shape: (216, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_4/seqlets/start | Shape: (216,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_4/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_5
# Dataset: pos_patterns/pattern_9/subpattern_5/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_9/subpattern_5/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_5/seqlets
# Dataset: pos_patterns/pattern_9/subpattern_5/seqlets/contrib_scores | Shape: (134, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_5/seqlets/end | Shape: (134,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_5/seqlets/example_idx | Shape: (134,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_5/seqlets/hypothetical_contribs | Shape: (134, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_5/seqlets/is_revcomp | Shape: (134,) | Type: bool
# Dataset: pos_patterns/pattern_9/subpattern_5/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_5/seqlets/sequence | Shape: (134, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_5/seqlets/start | Shape: (134,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_5/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_6
# Dataset: pos_patterns/pattern_9/subpattern_6/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_9/subpattern_6/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_6/seqlets
# Dataset: pos_patterns/pattern_9/subpattern_6/seqlets/contrib_scores | Shape: (134, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_6/seqlets/end | Shape: (134,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_6/seqlets/example_idx | Shape: (134,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_6/seqlets/hypothetical_contribs | Shape: (134, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_6/seqlets/is_revcomp | Shape: (134,) | Type: bool
# Dataset: pos_patterns/pattern_9/subpattern_6/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_6/seqlets/sequence | Shape: (134, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_6/seqlets/start | Shape: (134,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_6/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_7
# Dataset: pos_patterns/pattern_9/subpattern_7/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_9/subpattern_7/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_7/seqlets
# Dataset: pos_patterns/pattern_9/subpattern_7/seqlets/contrib_scores | Shape: (85, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_7/seqlets/end | Shape: (85,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_7/seqlets/example_idx | Shape: (85,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_7/seqlets/hypothetical_contribs | Shape: (85, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_7/seqlets/is_revcomp | Shape: (85,) | Type: bool
# Dataset: pos_patterns/pattern_9/subpattern_7/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_7/seqlets/sequence | Shape: (85, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_7/seqlets/start | Shape: (85,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_7/sequence | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_8
# Dataset: pos_patterns/pattern_9/subpattern_8/contrib_scores | Shape: (30, 4) | Type: float64
# Dataset: pos_patterns/pattern_9/subpattern_8/hypothetical_contribs | Shape: (30, 4) | Type: float64
# Group: pos_patterns/pattern_9/subpattern_8/seqlets
# Dataset: pos_patterns/pattern_9/subpattern_8/seqlets/contrib_scores | Shape: (47, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_8/seqlets/end | Shape: (47,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_8/seqlets/example_idx | Shape: (47,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_8/seqlets/hypothetical_contribs | Shape: (47, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_8/seqlets/is_revcomp | Shape: (47,) | Type: bool
# Dataset: pos_patterns/pattern_9/subpattern_8/seqlets/n_seqlets | Shape: (1,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_8/seqlets/sequence | Shape: (47, 30, 4) | Type: float32
# Dataset: pos_patterns/pattern_9/subpattern_8/seqlets/start | Shape: (47,) | Type: int64
# Dataset: pos_patterns/pattern_9/subpattern_8/sequence | Shape: (30, 4) | Type: float64

# %%
peak_rows = None
with open(BED_PKS, 'r') as peaks_file:
    peak_rows = peaks_file.read().splitlines()

# %%
first_set= None
with h5py.File(H5_SCORES, "r") as grp:
    for (pattern_name, datasets) in grp['pos_patterns'].items():
        # Process each seqlet within the pattern.
        for idx in range(datasets['seqlets']['start'].shape[0])[:6]:
            seqlet_name = f'{pattern_name}.{idx}'
            row_num = datasets['seqlets']['example_idx'][idx]
            contrib_score = datasets['seqlets']['contrib_scores'][idx]
            hyp_contribs = datasets['seqlets']['hypothetical_contribs'][idx]
            print(f'seqlet: {seqlet_name}')
            print(f'target peak: {row_num}')
            print(np.sum(np.abs(contrib_score)), np.sum(contrib_score), np.sum(contrib_score**2))
            print(np.sum(np.abs(hyp_contribs)), np.sum(hyp_contribs), np.sum(hyp_contribs**2))
            
        break
# Out:
# seqlet: pattern_0.0
# target peak: 61788
# 1.854023 1.6346931 0.27259195
# 4.9486613 2.8651013 0.4445321
# seqlet: pattern_0.1
# target peak: 13795
# 1.9545879 1.8569584 0.26404402
# 4.9942217 2.6684313 0.44210005
# seqlet: pattern_0.2
# target peak: 69053
# 1.810647 1.6594934 0.2686778
# 4.750456 1.8176861 0.45345098
# seqlet: pattern_0.3
# target peak: 27606
# 1.6140528 1.4647436 0.16965793
# 4.2320867 3.4660268 0.28540647
# seqlet: pattern_0.4
# target peak: 43389
# 1.6914406 1.651722 0.19399147
# 4.369465 2.1167815 0.34056684
# seqlet: pattern_0.5
# target peak: 52791
# 1.6808987 1.6808987 0.23862782
# 4.6276927 2.4096303 0.4094422

# %%
peak_rows[0]
# Out:
# 'chr1\t1615174\t1615675\tchr1:1615174-1615675\t958.759\t*\t.\t-1\t-1\t250'

# %%
with gzip.open(BEDPE_OUT, 'wt') as f_out:
    with h5py.File(H5_SCORES, "r") as grp:
        for contribution_dir in ['pos', 'neg']:
            patterns_category = f'{contribution_dir}_patterns'
            if patterns_category not in grp:
              continue
            for (pattern_name, datasets) in grp[patterns_category].items():
                print(f'{contribution_dir}_{pattern_name}')
                # Process each seqlet within the pattern.
                for idx in range(datasets['seqlets']['start'].shape[0]):
                    seqlet_name = f'{contribution_dir}_patterns.{pattern_name}.{idx}'
    
                    target_idx = datasets['seqlets']['example_idx'][idx]
                    peak_row = peak_rows[target_idx].split('\t')
                    # chrom(s)
                    chrom = peak_row[0]
    
                    # positions
                    target_start = int(peak_row[1])
                    target_end = int(peak_row[2])
                    
                    target_center = (target_end + target_start) // 2
                    window_center_offset = WINDOW_SIZE // 2
                    seqlet_start_offset = datasets['seqlets']['start'][idx] + 1
                    seqlet_end_offset = datasets['seqlets']['end'][idx]
                    seqlet_start = target_center - window_center_offset + seqlet_start_offset
                    seqlet_end = target_center - window_center_offset + seqlet_end_offset
    
                    # scores
                    target_score = peak_row[4]
                    contrib_score = datasets['seqlets']['contrib_scores'][idx]
                    seqlet_score = np.sum(contrib_score**2)
    
                    # strand
                    seqlet_strand = '-' if bool(datasets['seqlets']['is_revcomp'][idx]) is True else '+'
                    target_strand = peak_row[5]
    
                    row_vars = [chrom, seqlet_start, seqlet_end, 
                                chrom, target_start, target_end, 
                                seqlet_name, seqlet_score, 
                                seqlet_strand, target_strand, 
                                target_score]
                    f_out.write("\t".join(map(str, row_vars)) + "\n")
# Out:
# pos_pattern_0
# pos_pattern_1
# pos_pattern_10
# pos_pattern_11
# pos_pattern_12
# pos_pattern_13
# pos_pattern_14
# pos_pattern_15
# pos_pattern_16
# pos_pattern_17
# pos_pattern_18
# pos_pattern_19
# pos_pattern_2
# pos_pattern_20
# pos_pattern_21
# pos_pattern_22
# pos_pattern_23
# pos_pattern_24
# pos_pattern_25
# pos_pattern_26
# pos_pattern_27
# pos_pattern_28
# pos_pattern_29
# pos_pattern_3
# pos_pattern_30
# pos_pattern_31
# pos_pattern_32
# pos_pattern_33
# pos_pattern_34
# pos_pattern_35
# pos_pattern_36
# pos_pattern_37
# pos_pattern_38
# pos_pattern_39
# pos_pattern_4
# pos_pattern_40
# pos_pattern_41
# pos_pattern_42
# pos_pattern_43
# pos_pattern_44
# pos_pattern_45
# pos_pattern_46
# pos_pattern_47
# pos_pattern_48
# pos_pattern_49
# pos_pattern_5
# pos_pattern_50
# pos_pattern_51
# pos_pattern_52
# pos_pattern_53
# pos_pattern_54
# pos_pattern_55
# pos_pattern_56
# pos_pattern_57
# pos_pattern_58
# pos_pattern_59
# pos_pattern_6
# pos_pattern_60
# pos_pattern_61
# pos_pattern_62
# pos_pattern_63
# pos_pattern_64
# pos_pattern_7
# pos_pattern_8
# pos_pattern_9
