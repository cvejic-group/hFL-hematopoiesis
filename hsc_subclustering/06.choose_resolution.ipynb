# %% [markdown]
# kernal: scanpy

# %% [markdown]
# # Set up

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf as mpdf
from matplotlib.pyplot import rc_context

import scanpy as sc
import muon as mu
import cytocipher as cc

import warnings
from numba.core.errors import NumbaDeprecationWarning
warnings.filterwarnings(action='once')
warnings.simplefilter(action='once')
warnings.simplefilter(action="ignore", category=NumbaDeprecationWarning)
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=DeprecationWarning)

# %%
sc.settings.verbosity = 0  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=100, frameon=False, figsize=(8, 7), facecolor="white")
sc.logging.print_versions()

# %% [markdown]
# # Load data

# %%
work_dir = '/work/DevM_analysis/01.annotation/11.subclustering/HSC'
dataset = "FL_wnn"
new_file, old_file = "v00", "v00"
new_anno, old_anno = "leiden_wnn_3", "leiden_wnn_3"

# %% [markdown]
# Load data

# %%
mdata = mu.read(
    f"data/{dataset}_clustered.{old_file}.h5mu"
)
mdata

# %%
def run_dge(mdata=None, group=None, outdir=f"{work_dir}/data"):
    rna = mdata['rna']
    rna.obs[group] = mdata.obs[group].copy()
    sc.tl.rank_genes_groups(rna, groupby=group, method="wilcoxon")
    marker_df = sc.get.rank_genes_groups_df(rna, group=None)
    marker_df.to_csv(f"{outdir}/FL_wnn_markerGenes.{group}.csv", index=False)
    # top 100
    result = rna.uns['rank_genes_groups']
    groups = result['names'].dtype.names
    marker_df_top = pd.DataFrame({'cluster_' + group: result[key][group] for group in groups for key in ['names']}).head(100)
    marker_df_top.to_csv(f"{outdir}/FL_wnn_markerGenes_top100.{group}.csv", index=False)
    return mdata

# %% [markdown]
# # leiden_wnn_0.3

# %%
groupby = "leiden_wnn_0.3"
mdata = run_dge(mdata=mdata, group=groupby)

# %% [markdown]
# Heatmap

# %%
sc.pl.rank_genes_groups_heatmap(
        mdata['rna'],
    groupby = groupby,
        n_genes=5,
    show_gene_labels=True,
    cmap="bwr",
        use_raw=False,
        swap_axes=True,
        show=False,
        dendrogram=False,
    standard_scale = 'var',
    min_logfoldchange = 0.5,
    figsize = [10, 8]
    );

# %%
sc.pl.rank_genes_groups_heatmap(
        mdata['rna'],
    groupby = groupby,
        n_genes=5,
    show_gene_labels=True,
    cmap="bwr",
        use_raw=False,
        swap_axes=True,
        show=False,
        dendrogram=False,
    standard_scale = 'var',
    figsize = [10, 8]
    );

# %% [markdown]
# Top 100

# %%
sc.pl.rank_genes_groups_heatmap(
        mdata['rna'],
        n_genes=100,
        use_raw=False,
        swap_axes=True,
        cmap="bwr",
        show=False,
        dendrogram=False,
    standard_scale = 'var'
    );

# %% [markdown]
# Top genes of each

# %%
sc.pl.rank_genes_groups(mdata['rna'], groupby=groupby, n_genes=25, sharey=False)

# %% [markdown]
# dotplot

# %%
sc.pl.rank_genes_groups_dotplot(
    mdata['rna'], groupby=groupby, standard_scale="var", n_genes=5, min_logfoldchange=0.5
)

# %%
sc.pl.rank_genes_groups_dotplot(
    mdata['rna'], groupby=groupby, standard_scale="var", n_genes=5
)

# %% [markdown]
# # leiden_wnn_0.5

# %%
groupby = "leiden_wnn_0.5"
mdata = run_dge(mdata=mdata, group=groupby)

# %% [markdown]
# Heatmap

# %%
sc.pl.rank_genes_groups_heatmap(
        mdata['rna'],
    groupby = groupby,
        n_genes=5,
    show_gene_labels=True,
    cmap="bwr",
        use_raw=False,
        swap_axes=True,
        show=False,
        dendrogram=False,
    standard_scale = 'var',
    min_logfoldchange = 0.5,
    figsize = [10, 8]
    );

# %%
sc.pl.rank_genes_groups_heatmap(
        mdata['rna'],
    groupby = groupby,
        n_genes=5,
    show_gene_labels=True,
    cmap="bwr",
        use_raw=False,
        swap_axes=True,
        show=False,
        dendrogram=False,
    standard_scale = 'var',
    figsize = [10, 8]
    );

# %% [markdown]
# Top 100

# %%
sc.pl.rank_genes_groups_heatmap(
        mdata['rna'],
        n_genes=100,
        use_raw=False,
        swap_axes=True,
        cmap="bwr",
        show=False,
        dendrogram=False,
    standard_scale = 'var'
    );

# %% [markdown]
# Top genes of each

# %%
sc.pl.rank_genes_groups(mdata['rna'], groupby=groupby, n_genes=25, sharey=False)

# %% [markdown]
# dotplot

# %%
sc.pl.rank_genes_groups_dotplot(
    mdata['rna'], groupby=groupby, standard_scale="var", n_genes=5, min_logfoldchange=0.5
)

# %%
sc.pl.rank_genes_groups_dotplot(
    mdata['rna'], groupby=groupby, standard_scale="var", n_genes=5
)

# %% [markdown]
# # leiden_wnn_1

# %%
groupby = "leiden_wnn_1"
mdata = run_dge(mdata=mdata, group=groupby)

# %% [markdown]
# Heatmap

# %%
sc.pl.rank_genes_groups_heatmap(
        mdata['rna'],
    groupby = groupby,
        n_genes=5,
    show_gene_labels=True,
    cmap="bwr",
        use_raw=False,
        swap_axes=True,
        show=False,
        dendrogram=False,
    standard_scale = 'var',
    min_logfoldchange = 0.5,
    figsize = [10, 8]
    );

# %%
sc.pl.rank_genes_groups_heatmap(
        mdata['rna'],
    groupby = groupby,
        n_genes=5,
    show_gene_labels=True,
    cmap="bwr",
        use_raw=False,
        swap_axes=True,
        show=False,
        dendrogram=False,
    standard_scale = 'var',
    figsize = [10, 8]
    );

# %% [markdown]
# Top 100

# %%
sc.pl.rank_genes_groups_heatmap(
        mdata['rna'],
        n_genes=100,
        use_raw=False,
        swap_axes=True,
        cmap="bwr",
        show=False,
        dendrogram=False,
    standard_scale = 'var'
    );

# %% [markdown]
# Top genes of each

# %%
sc.pl.rank_genes_groups(mdata['rna'], groupby=groupby, n_genes=25, sharey=False)

# %% [markdown]
# dotplot

# %%
sc.pl.rank_genes_groups_dotplot(
    mdata['rna'], groupby=groupby, standard_scale="var", n_genes=5, min_logfoldchange=0.5
)

# %%
sc.pl.rank_genes_groups_dotplot(
    mdata['rna'], groupby=groupby, standard_scale="var", n_genes=5
)
